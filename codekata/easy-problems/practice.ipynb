# %% [markdown]
# ### Practice Exercises (Python basic Fundamentals)

# %% [markdown]
# #### Question 23:- Product of Digits
#
#
# Problem Statement:
# Given a number N, print the product of the digits.
#
#
# Input Description:
# Input Size : N <= 100000000000
#
#
# Sample Input:
# 2143
#
# Sample Output:
# 24

# %%
N = '5'

results = 1
for digit in N:
    results *= int(digit)
print(results)
# Out:
# 5

# %% [markdown]
# ### Question 9. String Middle Element Modification
#
# String Middle Element Modification
#
# Geekoin20
# Easy
# Topics
# Question:
# Given a string S, print it after changing the middle element to * (if the length of the string is even, change the 2 middle elements to *).
#
#
# Sample Input:
# hello
#
#
# Sample Output:
# he*lo

# %%
S = 'fghjkl;;'
mid = len(S) // 2 # // will return rounded off answer,(in odd case number)

if len(S) % 2 == 1: # idd casem
    ans = S[:mid] + '*' + S[mid+1:] # S[starting point end point]
elif len(S) % 2 == 0:
    ans = S[:mid-1] + '**' + S[mid+1:] # [1 2 * * 5 6] mid = 3

print(ans)
# Out:
# fgh**l;;

# %% [markdown]
# ### 10. Check if Number is Composite
#
# Problem Statement:
# Given a number N, print 'yes' if it is composite else print 'no'.
#
#
# Sample Input:
# 123
#
#
# Sample Output:
# yes

# %%
N = 1 # input field
N = str(N)  # converting int to str to call each elemets in it.

is_composite = False # setting default value

if int(N) <= 1: # 0 and 1 are not composite number
    print('no')
else:
    for char in range(2,int(N)): # calling all the char in the range of 2 to n
        if int(N) % char == 0: # suppose char = 20, 
            is_composite = True
            break
        else:
            is_composite = False
    
    if is_composite:
        print('yes')
    else:
        print('no')
# Out:
# no

# %% [markdown]
# #### 7. Number Range Check
#
# Question:
# Given 3 numbers N , L and R. Print 'yes' if N is between L and R else print 'no'.
#
#
# Sample Input:
#
# 3
#
# 2 6
#
#
# Sample Output:
# yes

# %%
N = '9'
num = '27'


if int(N) in range(int(num[0]),int(num[1])):
    print('yes')
else:
    print('No')
# Out:
# No

# %% [markdown]
# #### 2. Prime Number Check
#
#
# Problem Statement:
# Given a number N, check whether it is prime or not. Print 'yes' if it is prime else print 'no'.
#
#
# Input Description:
# The input consists of a single integer N.
#
#
# Output Description:
# The output is 'yes' if N is prime, otherwise 'no'.
#
#
# Sample Input:
# 123
#
#
# Sample Output:
# no

# %%
N = 17 # taking int input

if N <= 1: # if input is one or less than one, 
    print('No')
elif N == 2: # is N is 2, then call it prime and break the loop
    print('Yes')
elif N % 2 == 0: # for all the even cases
    print('No')
else: # for all the cases,
    is_prime = True # initial setting is_prime = True
    for char in range(3,int(N ** 0.5)+1,2): #looping in the range from 3 to sqrt of N, why 3?, cause we already covered 1,2 in above cases, syntax: start, end, step. (why step is 2, to avoid even cases,) why plus 1 in end point, to cover all the possible odd cases.
        if N % char == 0: # is N is divided by those char, then is_prime is false, 
            is_prime = False
            break # breaking the loop
    print('Yes' if is_prime else 'No') # print statement.
# Out:
# Yes

# %%
# same solution for above question but with func

N = 10

def chk_prime(num):
    if num <=1:
        print('no')
    elif num == 2:
        print('yes')
    elif num % 2 == 0:
        print('yes')
    else:
        is_prime = True
        for digit in range(3, int(num**0.5)+1,2):
            if num % digit == 0:
                is_prime = False
                break
        print('yes' if is_prime else 'no')

chk_prime(N)
# Out:
# yes

# %%
N = 10 # taking input

def chk_prime(num):
    if num <=1:
        return False # return False, if check is true
    else:
        for digit in range(2,int(num**0.5)+1): # covering even cases too, 
            if num % digit == 0:
                return False
        return True # if loops return True

chk_prime(N)
# Out:
# False

# %%
# same solution but using any() func

N = 10

if N <=1:
    print('no')
elif N == 2:
    print('yes')
elif N % 2 == 0:
    print('no')
else:   
    is_prime = True
    if any(N % digit == 0 for digit in range(3, int(N**0.5)+1,2)):
        is_prime = False
        
    print('yes' if is_prime else 'no')
# Out:
# no

# %% [markdown]
# ####  Next Greater Power of 2
#
#
# Question:
# Given a number N, find its next immediate greater power of 2(i.e 2^1, 2^2, 2^3...).
#
#
# Input Description:
# The input consists of a number N where N <= 1000.
#
#
# Sample Input:
# 4
#
#
# Sample Output:
# 8

# %%
N = 31

exp = 0 # exponetation 
while (2 ** exp) <= N:  # exponetation starting from zero, 2 power exp exceeds the input N, 
    exp = exp + 1 # when loops break, we add new exp and print it out.

print(2 ** exp)
# Out:
# 32

# %% [markdown]
# #### 8. Round to Nearest Greater Integer
#
#
# Question:
# Given a floating point number with 1 decimal place round it off to nearest greater integer and print it.
#
#
# Sample Input:
# 2.6
#
#
# Sample Output:
# 3

# %%
N = 6.9 # taking input, as float

NInt = int(N) # converting float to int, 6.9 to 6 if it is 8.0 then it will become 8 only

if N > NInt: # checking if float is greater than int, then add one otherwise print int
    print(NInt+1)
else:
    print(NInt)
# Out:
# 7

# %%
# different solution
import math

N = 7.5 # taking float as input
results = math.ceil(N) # math.ceil func, which shift float to its next greater int, like 6.9 to 7 if it is 8.0 then it will 8 only.
print(results)
# Out:
# 8

# %% [markdown]
# #### 11. Print Factors of a Number
#
#
# Problem Statement:
# Given a number N, print its factors.
#
#
# Input Description:
# Input Size : n<=1000
#
#
# Sample Input:
# 6
#
#
# Sample Output:
# 1 2 3 6

# %%
N = 4
array = []

for digit in range(1 , N+1):
    if N % digit == 0:
        array.append(digit)

print(*array)
# Out:
# 1 2 4

# %%
N = 34 # taking int input

num = [] # list to store factors
for i in range(1,N+1): # to find factors, we need divide every number for 1 to N, first running loops,
    if N % i == 0: # numbers leave 0 remainder on dividing, adding those in list
        num.append(i)
print(*num) # print only elements of list, * print only elements, and add space in between them.
# Out:
# 1 2 17 34

# %%
# alternative solution

N = 65
for i in range(1,N+1):
    if N % i == 0:
        print(i, end=" ") # simply printing i, using end method, which adds space after every elements
        # print(i)
# Out:
# 1 5 13 65

# %% [markdown]
# #### 13. Perfect Square Product
#
#
# Problem Statement:
# Given 2 numbers N,M. Print 'yes' if their product is a perfect square else print 'no'.
#
#
# Sample Input:
# 5 5
#
#
# Sample Output:
# yes

# %%
# N,M = map(int,input().split())

N = 8
M = 8

product = N * M

root = product ** 0.5

if root % 1 == 0:
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
# perfect sq means, 16 which 4 * 4, so here 16 is perfect sq, however 10 which 2 * 5 , so ten cannot be a perfect sq, as for perfect sq, sq root of number must be a whole number, like 16 

N = '9 9'

num = N.split()

N = int(num[0])
M = int(num[1])

product = N * M # product of provided numbers

root = product ** 0.5 # taking root of the product, if the root is whole number, then product was perfect sq.

if root % 1 == 0: # if a number is completely divided by 1, then it is a whole number, 
    print('yes')
else:
    print('no')
# Out:
# yes

# %% [markdown]
# #### 20. Reverse a Number
#
#
# Problem Statement:
# Given a number N, print its reverse.
#
#
# Input Description:
# Input Size : n <= 1000
#
#
# Sample Input:
# 10
#
#
# Sample Output:
# 1

# %%
# 27 mar 26
N = '0940'

arson = N[::-1]
print(int(arson))
# Out:
# 490

# %%
# first revision 27 march
N = 981

arson = 0
while N > 0:
    last_digit = N % 10 # returning the remainder
    arson = (arson * 10) + last_digit

    N = N // 10 # peeling the last digit.
    
print(arson)
# Out:
# 189

# %%
# using string slicing
N = '1890' # taking input as str

reverse = N[::-1] # slicing the string, syntax: str[start:stop:step], as step is -1 so program will read the string from backward.
print(int(reverse)) # converting it back to int,
# Out:
# 981

# %%
#alternative way to solve this
N = 1890 # taking input as int
reversed_num = 0 # setting initial reversed_num to zero.
while N > 0: # setting loop to run until the N is greater than zero
    last_digit = N % 10 # peeling off the last digit 
    reversed_num =  (reversed_num * 10) + last_digit # adding last digit to reversed_num  var, multiply initial reversed num with 10, to add last digit to its tens, hundreds place
    N = N // 10 # every time loops run, we ll remove the last digit from N. at one point, we have N in decimal, which is less than O, loop will break.

print(reversed_num)
# Out:
# 981

# %% [markdown]
# #### 24. Arithmetic Series Sum
#
#
# Problem Statement:
# Given 3 numbers A,B,C find the sum of Arithmetic Series with a=A, d=B and n=C
#
#
# Sample Input:
# 1 1 2
#
#
# Sample Output:
# 3

# %%
# question means: Arithmetic series means, an array with a comman diff, like 1 5 1,
# in question A = current term, B is diff, and C is number of elements, array contains.

# they provided us with the 3 numbers, we need to find the arithmetic series sum. 
# for that we know that(from question) A is current term, B is diff, and C is number of elements,

# A,B,C = map(int, input().split()) # taking input as int, and using map func to store as int in each variables,
A = 1
B = 5
C = 1

sum = 0 # setting initial sum is zero
for i in range(C): # running loop as the number of element in our array
    sum = sum + A # adding current term in our sum, as every element array must be added to our current term, like A, A+B, A+2B...

    A = A + B # after adding our first current term, we are updating the term by adding diff in it. and adding updated term in next loop.

print(sum)
# Out:
# 1
